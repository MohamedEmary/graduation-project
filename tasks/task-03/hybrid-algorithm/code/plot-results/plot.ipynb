# %%
import pandas as pd
import matplotlib.pyplot as plt
import scienceplots

plt.rcParams.update({'font.size': 14})
plt.style.use(['science', 'no-latex'])
plt.rcParams['font.family'] = 'Times New Roman'

bisection = pd.read_csv('../results/bisection-table.csv')
false_position = pd.read_csv('../results/false-position-table.csv')
hybridBF = pd.read_csv('../results/hybrid-table.csv')

# %%
plt.figure(figsize=(18, 6))
plt.plot(bisection['Problem'], bisection['Iter'], label='Bisection')
plt.plot(false_position['Problem'], false_position['Iter'], label='False Position')
plt.plot(hybridBF['Problem'], hybridBF['Iter'], label='HybridBF')
plt.legend()
plt.xlabel('Problem')
plt.ylabel('Iterations')
plt.title('Iteration Comparison')
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.tick_params(axis='x', which='minor', bottom=False)
plt.savefig('iterations-comparison.svg')
plt.show()

# %%
plt.figure(figsize=(18, 6))
plt.plot(bisection['Problem'], bisection['Avg CPU Time'], label='Bisection')
plt.plot(false_position['Problem'], false_position['Avg CPU Time'], label='False Position')
plt.plot(hybridBF['Problem'], hybridBF['Avg CPU Time'], label='HybridBF')
plt.legend()
plt.xlabel('Problem')
plt.ylabel('Time (s)')
plt.title('CPU Time Comparison')
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.tick_params(axis='x', which='minor', bottom=False)
plt.savefig('CPU-time-comparison.svg')
plt.show()

# %%
plt.figure(figsize=(18, 6))
plt.plot(bisection['Problem'], bisection['Function Value'], label='Bisection')
plt.plot(false_position['Problem'], false_position['Function Value'], label='False Position')
plt.plot(hybridBF['Problem'], hybridBF['Function Value'], label='HybridBF')
plt.legend()
plt.xlabel('Problem')
plt.ylabel('Function Value')
plt.title('Function Value Comparison')
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.tick_params(axis='x', which='minor', bottom=False)
plt.savefig('function-value-comparison.svg')
plt.show()

# %% [markdown]
# # All In One Plot

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# bisection = pd.read_csv('bisection-table.csv')
# false_position = pd.read_csv('false-position-table.csv')
# hybrid = pd.read_csv('hybrid-table.csv')

fig, axs = plt.subplots(3, 1, figsize=(15, 12))

axs[0].plot(bisection['Problem'], bisection['Iter'], label='Bisection')
axs[0].plot(false_position['Problem'],
            false_position['Iter'], label='False Position')
axs[0].plot(hybridBF['Problem'], hybridBF['Iter'], label='HybridBF')
axs[0].set_title('Iteration Comparison')
axs[0].set_ylabel('Iterations')

axs[1].plot(bisection['Problem'], bisection['Avg CPU Time'], label='Bisection')
axs[1].plot(false_position['Problem'],
            false_position['Avg CPU Time'], label='False Position')
axs[1].plot(hybridBF['Problem'], hybridBF['Avg CPU Time'], label='HybridBF')
axs[1].set_title('CPU Time Comparison')
axs[1].set_ylabel('Time (s)')

axs[2].plot(bisection['Problem'],
            bisection['Function Value'], label='Bisection')
axs[2].plot(false_position['Problem'],
            false_position['Function Value'], label='False Position')
axs[2].plot(hybridBF['Problem'], hybridBF['Function Value'], label='HybridBF')
axs[2].set_title('Function Value Comparison')
axs[2].set_ylabel('Function Value')

for ax in axs:
    ax.tick_params(axis='x', which='minor', bottom=False)
    ax.legend()
    ax.set_xlabel('Problem')
    ax.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.5)


fig.tight_layout()
plt.savefig('plots.svg')
plt.show()
